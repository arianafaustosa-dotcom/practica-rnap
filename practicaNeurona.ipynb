# %%
import numpy as np

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

def sigmoid_derivada(x):
  s = sigmoid(x)
  return s * (1 - s)

# %%
from os import error
class Neurona:
  def _init_(self, n_entradas, lr:0.5):
    self.w=np.random.random(n_entradas) * 0.5
    self.b= 0.0
    self.lr= lr

  def forward(self, x):
    self.x=x
    self.z= np.dot(self.w, x) + self.b
    self.a= sigmoid(self.z)
    z = np.dot(self.w, x) + self.b
    a = sigmoid(z)

    dw = dz*

# %%
for i in range(len(x)):
  pred= neurona.forward(x[i])
  print(pred)

# %%
x = np.array([[0,0], [0,1], [1,0],[1,1]])

y= np.array([0,1,1,1])

# %%
x.shape
# Out:
# (4, 2)

# %%
(4, 2)
# Out:
# (4, 2)

# %%
y.shape
# Out:
# (4,)

# %%
(4, )
# Out:
# (4,)
